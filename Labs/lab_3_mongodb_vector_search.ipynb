# %% [markdown]
# # Vector Search using vCore-based Azure Cosmos DB for MongoDB
#
# This notebook demonstrates using an Azure OpenAI embedding model to vectorize documents already stored in Azure Cosmos DB API for MongoDB, storing the embedding vectors and the creation of a vector index. Lastly, the notebook will demonstrate how to query the vector index to find similar documents.
#
# This lab expects the data that was loaded in Lab 2.

# %%
import os
import pymongo
import time
import json
from openai import AzureOpenAI
from dotenv import load_dotenv
from tenacity import retry, wait_random_exponential, stop_after_attempt
import certifi

# %% [markdown]
# ## Load settings
#
# This lab expects the `.env` file that was created in Lab 1 to obtain the connection string for the database.
#
# Add the following entries into the `.env` file to support the connection to Azure OpenAI API, replacing the values for `<your key>` and `<your endpoint>` with the values from your Azure OpenAI API resource.
#
# ```text
# AOAI_ENDPOINT="<your endpoint>"
# AOAI_KEY="<your key>""
# ```

# %%
load_dotenv()
CONNECTION_STRING = os.environ.get("DB_CONNECTION_STRING")
EMBEDDINGS_DEPLOYMENT_NAME = "text-embedding-ada-002"
COMPLETIONS_DEPLOYMENT_NAME = "gpt-35-turbo"
AOAI_ENDPOINT = os.environ.get("AOAI_ENDPOINT")
AOAI_KEY = os.environ.get("AOAI_KEY")
AOAI_API_VERSION = "2023-05-15"

# %% [markdown]
# ## Establish connectivity to the database

# %%
db_client = pymongo.MongoClient(CONNECTION_STRING, tlsCAFile=certifi.where())
# Create database to hold cosmic works data
# MongoDB will create the database if it does not exist
db = db_client.cosmic_works

# %% [markdown]
# ## Establish Azure OpenAI connectivity

# %%
ai_client = AzureOpenAI(
    azure_endpoint = AOAI_ENDPOINT,
    api_version = AOAI_API_VERSION,
    api_key = AOAI_KEY
    )

# %% [markdown]
# ## Vectorize and store the embeddings in each document
#
# The process of creating a vector embedding field on each document only needs to be done once. However, if a document changes, the vector embedding field will need to be updated with an updated vector.

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(3))
def generate_embeddings(text: str):
    '''
    Generate embeddings from string of text using the deployed Azure OpenAI API embeddings model.
    This will be used to vectorize document data and incoming user messages for a similarity search with
    the vector index.
    '''
    response = ai_client.embeddings.create(input=text, model=EMBEDDINGS_DEPLOYMENT_NAME)
    embeddings = response.data[0].embedding
    time.sleep(0.5) # rest period to avoid rate limiting on AOAI
    return embeddings

# %%
# demonstrate embeddings generation using a test string
test = "hello, world"
print(generate_embeddings(test))
# Out:
# [-0.016783414, -0.006727666, -0.027430676, -0.046463147, -0.01095277, 0.01014025, -0.013910343, -0.0048393696, -0.018681461, -0.0283667, 0.028990716, 0.019799488, -0.021710536, -0.006327906, 0.009522735, 0.0066171633, 0.017589433, -0.014456357, 0.011784791, 0.018460454, -0.012330804, -1.1311802e-05, 0.009295229, -0.009893244, -0.009581236, -0.016315402, 0.006864169, -0.016874416, 0.024388602, -0.037882935, 0.00066789147, 0.0033865834, -0.016081396, -0.0064254086, 0.011115274, -0.011895293, 0.00094739837, -0.02756068, 0.02917272, -0.01138828, 0.0024960616, -0.0070396736, 0.0040821005, -0.013715338, -0.032708805, 0.012623311, 0.008768716, -0.015080372, 0.0042706053, 0.02269856, 0.021606533, 0.0015787265, -0.024401601, -0.0019939241, -0.013097823, 0.008671214, -0.035360873, 0.014703362, 0.019994494, -0.020579508, 0.01582139, 0.0038155941, -0.025324624, 0.0121748, -0.010153251, 0.010328755, 0.015990395, 0.008632213, -0.019539481, 0.01458636, 0.020735512, 0.018993469, -0.0054146335, -0.0077156904, 0.021814538, -0.0006662664, -0.012525809, -0.00022547432, -0.0015307878, -0.00052245037, 0.037830934, -0.03598489, -0.0034548352, 0.011186776, 0.014495358, 0.01580839, -0.003324832, 0.017511431, -0.01575639, -0.01498937, -0.004491611, 0.0022994317, 0.018616458, 0.013923343, -0.029562728, 0.013858342, 0.008762216, 0.027092667, 0.0029868237, -0.04167903, -0.017095422, -0.0071111755, -0.0048848703, -0.011316779, -0.02470061, -0.012421806, -0.0005842019, 0.0033102066, 0.023062568, 0.0073971823, -0.014547359, 0.021658534, -0.006123151, -0.023972591, -0.008950721, -0.0059248963, -0.015912393, -0.004303106, -0.011856292, -0.015236376, 0.015600385, 0.024453603, 0.017238425, -0.02268556, 0.011687288, 0.0026244398, -0.045215115, -0.01419635, -0.0020849265, -0.01744643, 0.03078476, -0.0030713258, 0.017303428, -0.0057363915, -0.029822735, 0.010608261, -0.011043772, 0.010478258, -0.022932565, -0.01743343, 0.0020589258, 0.027118668, 0.016549408, 0.0053268815, -0.012610311, 0.011284279, 0.023998592, -0.009191227, 0.015119373, -0.002955948, 0.006155652, 0.0077676917, 7.180646e-05, 0.00446236, 0.00973074, 0.029016716, -0.008872719, 0.021853538, -0.0005772955, -0.015717387, 0.005135127, -0.009366731, 0.0040008486, -0.020956516, 0.011485783, 0.03530887, 0.011901794, 0.0057071405, -0.009308229, -0.024505604, -0.010062248, 0.005950897, -0.030264746, 0.025324624, -0.006968172, 0.0002728036, 0.009841243, 0.01904547, -0.017173424, -0.021008518, -0.027144669, 0.025025617, 0.00041458834, 0.037154917, 0.00566164, 0.008833718, 0.020813514, -0.011602786, -0.0059248963, -0.018551458, 0.0006463597, 0.03398284, 0.02275056, 0.010354755, -0.689745, -0.014417356, 0.030160744, 0.022035543, 0.0043973583, 0.016471406, 0.011979795, 0.026598657, -0.0028226946, 0.02109952, -0.01458636, 0.021853538, -0.001117215, -0.009639738, 0.0035588378, -0.01137528, 0.008151201, -0.025662633, -0.011056772, 0.022074545, -0.016523408, 0.02997874, -0.017966444, -0.007052674, -0.0019321727, 0.0018752962, 0.005183878, -0.020189498, -0.015639385, 0.037362922, -0.019162472, 0.017173424, 0.013429332, -0.004624864, 0.048179187, 0.020033494, -0.0070396736, 0.0065879123, 0.0153013775, 0.040326994, -0.02190554, -0.025805637, 0.0027511928, -0.0073321806, 0.011095773, 0.0044363593, -0.0002768662, -0.012896318, -0.011557285, 0.0023628082, 0.027144669, -0.008320205, 0.018824464, 0.012434807, 0.0041276016, -0.0025854388, 0.012109798, 0.0017550433, -0.0006760167, 0.02068351, -0.0018687961, 0.019565482, 0.004618364, 0.0017680436, -0.018915467, 0.013767339, -0.015548384, -0.0033768334, 0.0020719261, -0.0162374, 0.0035360872, 0.0027349424, -0.021255525, -0.018343452, 0.019812489, 0.03975498, 0.00892472, -0.013338329, -0.0058468943, 0.026832663, 0.022022543, 0.0037083414, -0.013689337, -0.027456677, 0.01826545, -0.027144669, -0.030212745, -0.013858342, -0.003848095, -0.00019348133, 0.035828885, 0.013429332, -0.014456357, -0.034268845, 0.02312757, 0.01095277, -0.013123823, -0.005310631, 0.018031444, -0.00486537, -0 ...

# %% [markdown]
# ### Vectorize and update all documents in the Cosmic Works database

# %%
def add_collection_content_vector_field(collection_name: str):
    """
    Add a new field to the collection to hold the vectorized content of each document.
    """
    collection = db[collection_name]
    # doc = collection.find_one({"_id": "3F105575-8677-42F9-8E1F-76E4B450F136"})
    # print(doc)

    # if "contentVector" in doc:
    #     del doc["contentVector"]

    # # generate embeddings for the document string representation
    # content = json.dumps(doc, default=str)
    # content_vector = generate_embeddings(content)
    # print("content: ", content)

    # doc["contentVector"] = "Makarena"

    # bulk_operations = []
    # bulk_operations.append(
    #     pymongo.UpdateOne(
    #         {"_id": doc["_id"]}, {"$set": {"contentVector": "content_vector"}}, upsert=True
    #     )
    # )
    # collection.bulk_write(bulk_operations)
    
    bulk_operations = []
    cursor = collection.find({}, batch_size=20)
    print("Batch size: 20")
    for doc in cursor:
        # remove any previous contentVector embeddings
        if "contentVector" in doc:
            del doc["contentVector"]

        # generate embeddings for the document string representation
        content = json.dumps(doc, default=str)
        print("content: ", content)
        content_vector = generate_embeddings(content)

        bulk_operations.append(pymongo.UpdateOne(
            {"_id": doc["_id"]},
            {"$set": {"contentVector": content_vector}},
            upsert=True
        ))
    # execute bulk operations
    collection.bulk_write(bulk_operations)
    cursor.close()

# %%
# Add vector field to products documents - this will take approximately 3-5 minutes due to rate limiting
add_collection_content_vector_field("products")
# Out:
# c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\collection.py:1697: UserWarning: use an explicit session with no_cursor_timeout=True otherwise the cursor may still timeout after 30 minutes, for more info see https://mongodb.com/docs/v4.4/reference/method/cursor.noCursorTimeout/#session-idle-timeout-overrides-nocursortimeout
#   return Cursor(self, *args, **kwargs)
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\pool.py:1585, in Pool.connect(self, handler)
#    1584 try:
# -> 1585     sock = _configured_socket(self.address, self.opts)
#    1586 except BaseException as error:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\pool.py:1282, in _configured_socket(address, options)
#    1281 if HAS_SNI:
# -> 1282     ssl_sock = ssl_context.wrap_socket(sock, server_hostname=host)
#    1283 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Add vector field to products documents - this will take approximately 3-5 minutes due to rate limiting
# ----> 2 add_collection_content_vector_field("products")
#
# Cell In[6], line 29, in add_collection_content_vector_field(collection_name)
#      27 bulk_operations = []
#      28 cursor = collection.find(no_cursor_timeout=True)
# ---> 29 for doc in cursor:
#      30     # remove any previous contentVector embeddings
#      31     if "contentVector" in doc:
#      32         del doc["contentVector"]
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
#    1161             " option to ensure the query utilizes the correct index"
#    1162         )
#    1163     q = self._query_class(
#    1164         self.__query_flags,
#    1165         self.__collection.database.name,
#    (...)
#    1179         self.__exhaust,
#    1180     )
# -> 1181     self.__send_message(q)
#    1182 elif self.__id:  # Get More
#    1183     if self.__limit:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:2320, in _ClientConnectionRetryable.run(self)
#    2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
# -> 2320     self._check_last_error()
#    2321     # A ServerSelectionTimeoutError error indicates that there may
#    2322     # be a persistent outage. Attempting to retry in this case will
#    2323     # most likely be a waste of time.
#    2324     raise
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:2392, in _ClientConnectionRetryable._check_last_error(self, check_csot)
#    2390 if not check_csot or (remaining is not None and remaining <= 0):
#    2391     assert self._last_error is not None
# -> 2392     raise self._last_error
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:2439, in _ClientConnectionRetryable._read(self)
#    2437 self._server = self._get_server()
#    2438 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2439 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2440     conn,
#    2441     read_pref,
#    2442 ):
#    2443     if self._retrying and not self._retryable:
#    2444         self._check_last_error()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1330, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1327 topology = self._get_topology()
#    1328 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1330 with self._checkout(server, session) as conn:
#    1331     if single:
#    1332         if conn.is_repl and not (session and session.in_transaction):
#    1333             # Use primary preferred to ensure any repl set member
#    1334             # can handle the request.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1252, in MongoClient._checkout(self, server, session)
#    1250     yield session._pinned_connection
#    1251     return
# -> 1252 with server.checkout(handler=err_handler) as conn:
#    1253     # Pin this session to the selected server or connection.
#    1254     if (
#    1255         in_txn
#    1256         and session
#    (...)
#    1261         )
#    1262     ):
#    1263         session._pin(server, conn)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.1008.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\pool.py:1637, in Pool.checkout(self, handler)
#    1634     assert listeners is not None
#    1635     listeners.publish_connection_check_out_started(self.address)
# -> 1637 conn = self._get_conn(handler=handler)
#    1639 if self.enabled_for_cmap:
#    1640     assert listeners is not None
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\pool.py:1756, in Pool._get_conn(self, handler)
#    1754 else:  # We need to create a new connection
#    1755     try:
# -> 1756         conn = self.connect(handler=handler)
#    1757     finally:
#    1758         with self._max_connecting_cond:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\pool.py:1595, in Pool.connect(self, handler)
#    1593     if isinstance(error, (IOError, OSError, SSLError)):
#    1594         details = _get_timeout_details(self.opts)
# -> 1595         _raise_connection_failure(self.address, error, timeout_details=details)
#    1597     raise
#    1599 conn = Connection(sock, self, self.address, conn_id)  # type: ignore[arg-type]
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\pool.py:411, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     409     raise NetworkTimeout(msg) from error
#     410 else:
# --> 411     raise AutoReconnect(msg) from error
#
# AutoReconnect: c.copilot-cluster.mongocluster.cosmos.azure.com:10260: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000) (configured timeouts: connectTimeoutMS: 20000.0ms)

# %%
# Add vector field to customers documents - this will take approximately 1-2 minutes due to rate limiting
add_collection_content_vector_field("customers")

# %%
# Add vector field to customers documents - this will take approximately 15-20 minutes due to rate limiting
add_collection_content_vector_field("sales")
# Out:
# c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\collection.py:1697: UserWarning: use an explicit session with no_cursor_timeout=True otherwise the cursor may still timeout after 30 minutes, for more info see https://mongodb.com/docs/v4.4/reference/method/cursor.noCursorTimeout/#session-idle-timeout-overrides-nocursortimeout
#   return Cursor(self, *args, **kwargs)
# content:  {"_id": "00500AA1-3E9D-4E83-9C21-07B0AF482B3F", "customerId": "72F4BF6F-6BF5-4E22-89C1-29505FD74710", "orderDate": "2012-03-30 00:00:00", "shipDate": "2012-04-06 00:00:00", "details": [{"sku": "BK-R93R-62", "name": "Road-150 Red, 62", "price": 2146.962, "quantity": 1}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 178.5808, "quantity": 1}]}
# content:  {"_id": "00CC8882-4B98-4273-BDD3-732CB8F5A2E0", "customerId": "D6A5D690-7A0C-42F4-8557-B1FE8326795F", "orderDate": "2013-05-30 00:00:00", "shipDate": "2013-06-06 00:00:00", "details": [{"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.394, "quantity": 5}, {"sku": "FR-R92R-44", "name": "HL Road Frame - Red, 44", "price": 858.9, "quantity": 2}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 202.332, "quantity": 3}, {"sku": "BK-R89B-58", "name": "Road-250 Black, 58", "price": 1466.01, "quantity": 3}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 15.7455, "quantity": 7}, {"sku": "BK-R64Y-42", "name": "Road-550-W Yellow, 42", "price": 672.294, "quantity": 6}, {"sku": "BK-R89B-48", "name": "Road-250 Black, 48", "price": 1466.01, "quantity": 8}, {"sku": "SJ-0194-S", "name": "Short-Sleeve Classic Jersey, S", "price": 32.394, "quantity": 2}, {"sku": "BK-R64Y-44", "name": "Road-550-W Yellow, 44", "price": 672.294, "quantity": 5}, {"sku": "RA-H123", "name": "Hitch Rack - 4-Bike", "price": 72.0, "quantity": 4}, {"sku": "BK-R79Y-44", "name": "Road-350-W Yellow, 44", "price": 1020.594, "quantity": 4}, {"sku": "BK-R19B-58", "name": "Road-750 Black, 58", "price": 323.994, "quantity": 2}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 5.394, "quantity": 7}, {"sku": "BK-R64Y-38", "name": "Road-550-W Yellow, 38", "price": 672.294, "quantity": 3}, {"sku": "WB-H098", "name": "Water Bottle - 30 oz.", "price": 2.994, "quantity": 9}, {"sku": "PD-R347", "name": "LL Road Pedal", "price": 24.294, "quantity": 6}, {"sku": "BK-R64Y-40", "name": "Road-550-W Yellow, 40", "price": 672.294, "quantity": 5}, {"sku": "PD-R853", "name": "HL Road Pedal", "price": 48.594, "quantity": 3}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 29.994, "quantity": 4}, {"sku": "VE-C304-M", "name": "Classic Vest, M", "price": 38.1, "quantity": 3}, {"sku": "CL-9009", "name": "Bike Wash - Dissolver", "price": 4.77, "quantity": 8}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 5}, {"sku": "SJ-0194-L", "name": "Short-Sleeve Classic Jersey, L", "price": 32.394, "quantity": 9}, {"sku": "FR-R72Y-48", "name": "ML Road Frame-W - Yellow, 48", "price": 356.898, "quantity": 2}, {"sku": "BK-R19B-52", "name": "Road-750 Black, 52", "price": 323.994, "quantity": 6}, {"sku": "FR-R38B-58", "name": "LL Road Frame - Black, 58", "price": 202.332, "quantity": 2}, {"sku": "FR-R72Y-38", "name": "ML Road Frame-W - Yellow, 38", "price": 356.898, "quantity": 3}, {"sku": "SJ-0194-X", "name": "Short-Sleeve Classic Jersey, XL", "price": 32.394, "quantity": 6}, {"sku": "VE-C304-S", "name": "Classic Vest, S", "price": 38.1, "quantity": 8}, {"sku": "HB-R504", "name": "LL Road Handlebars", "price": 26.724, "quantity": 4}, {"sku": "BK-R89B-44", "name": "Road-250 Black, 44", "price": 1466.01, "quantity": 6}, {"sku": "BK-R89B-52", "name": "Road-250 Black, 52", "price": 1466.01, "quantity": 3}, {"sku": "BK-R19B-44", "name": "Road-750 Black, 44", "price": 323.994, "quantity": 2}, {"sku": "PK-7098", "name": "Patch Kit/8 Patches", "price": 1.374, "quantity": 2}, {"sku": "FR-R92R-62", "name": "HL Road Frame - Red, 62", "price": 858.9, "quantity": 2}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 15.7455, "quantity": 6}, {"sku": "HB-R956", "name": "HL Road Handlebars", "price": 72.162, "quantity": 4}, {"sku": "FR-R72Y-44", "name": "ML Road Frame-W - Yellow, 44", "price": 356.898, "quantity": 1}, {"sku": "PD-R563", "name": "ML Road Pedal", "price": 37.254, "quantity": 5}, {"sku": "BK-R89R-58", "name": "Road-250 Red, 58", "price": 1466.01, "quantity": 4}, {"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.394, "quantity": 6}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 29.994, "quantity": 5}, {"sku": "GL-H102-S", "name": "Half-Finger Gloves, S", "price": 14.694, "quantity": 2}, {"sku": "GL-H102-M", "name": "Half-Finger Gloves, M", "price": 14.694, "quantit ...
# content:  {"_id": "00E4B453-A79A-4590-8CCB-28ED95003CB7", "customerId": "3945DB3E-2632-466C-BCBE-0C252729C937", "orderDate": "2013-08-25 00:00:00", "shipDate": "2013-09-01 00:00:00", "details": [{"sku": "SJ-0194-M", "name": "Short-Sleeve Classic Jersey, M", "price": 53.99, "quantity": 1}]}
# content:  {"_id": "0148B088-5124-45FB-B815-22851683D8AA", "customerId": "D01E483D-AEE0-41E6-A2E1-0220AA233A7A", "orderDate": "2014-01-09 00:00:00", "shipDate": "2014-01-16 00:00:00", "details": [{"sku": "SJ-0194-L", "name": "Short-Sleeve Classic Jersey, L", "price": 53.99, "quantity": 1}]}
# content:  {"_id": "01AFA50A-2009-4AC3-A008-B6F8E2003BB6", "customerId": "91A01FF7-B425-4A9F-B2F4-E4285E1D78AE", "orderDate": "2012-06-30 00:00:00", "shipDate": "2012-07-07 00:00:00", "details": [{"sku": "BK-M68B-42", "name": "Mountain-200 Black, 42", "price": 1229.4589, "quantity": 1}, {"sku": "GL-F110-M", "name": "Full-Finger Gloves, M", "price": 22.794, "quantity": 4}, {"sku": "BK-M68S-38", "name": "Mountain-200 Silver, 38", "price": 1242.8518, "quantity": 1}, {"sku": "GL-F110-L", "name": "Full-Finger Gloves, L", "price": 22.794, "quantity": 4}, {"sku": "HB-M763", "name": "ML Mountain Handlebars", "price": 33.7745, "quantity": 1}, {"sku": "BK-M68S-42", "name": "Mountain-200 Silver, 42", "price": 1242.8518, "quantity": 2}, {"sku": "RW-M928", "name": "HL Mountain Rear Wheel", "price": 196.329, "quantity": 3}, {"sku": "GL-F110-S", "name": "Full-Finger Gloves, S", "price": 22.794, "quantity": 2}, {"sku": "FR-M63B-48", "name": "ML Mountain Frame - Black, 48", "price": 209.256, "quantity": 2}]}
# content:  {"_id": "01D792C9-8C84-4120-B9FB-87C707D94B30", "customerId": "34E7A125-0F66-4673-A80B-20B4C46EAD3A", "orderDate": "2013-08-30 00:00:00", "shipDate": "2013-09-06 00:00:00", "details": [{"sku": "BK-R79Y-42", "name": "Road-350-W Yellow, 42", "price": 1020.594, "quantity": 4}, {"sku": "BK-R64Y-40", "name": "Road-550-W Yellow, 40", "price": 672.294, "quantity": 1}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.994, "quantity": 2}, {"sku": "BK-R89B-48", "name": "Road-250 Black, 48", "price": 1466.01, "quantity": 1}, {"sku": "SJ-0194-S", "name": "Short-Sleeve Classic Jersey, S", "price": 32.394, "quantity": 2}, {"sku": "CL-9009", "name": "Bike Wash - Dissolver", "price": 4.77, "quantity": 2}, {"sku": "BK-R64Y-42", "name": "Road-550-W Yellow, 42", "price": 672.294, "quantity": 2}, {"sku": "BK-R79Y-48", "name": "Road-350-W Yellow, 48", "price": 1020.594, "quantity": 2}, {"sku": "BK-R19B-52", "name": "Road-750 Black, 52", "price": 323.994, "quantity": 2}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.994, "quantity": 7}, {"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.394, "quantity": 2}, {"sku": "BK-R64Y-48", "name": "Road-550-W Yellow, 48", "price": 672.294, "quantity": 2}, {"sku": "BK-R64Y-44", "name": "Road-550-W Yellow, 44", "price": 672.294, "quantity": 5}, {"sku": "BK-R19B-44", "name": "Road-750 Black, 44", "price": 323.994, "quantity": 2}, {"sku": "SJ-0194-L", "name": "Short-Sleeve Classic Jersey, L", "price": 32.394, "quantity": 5}, {"sku": "VE-C304-M", "name": "Classic Vest, M", "price": 38.1, "quantity": 9}, {"sku": "RA-H123", "name": "Hitch Rack - 4-Bike", "price": 72.0, "quantity": 6}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 2}, {"sku": "HY-1023-70", "name": "Hydration Pack - 70 oz.", "price": 32.994, "quantity": 3}, {"sku": "BK-R89B-52", "name": "Road-250 Black, 52", "price": 1466.01, "quantity": 2}, {"sku": "BK-R64Y-38", "name": "Road-550-W Yellow, 38", "price": 672.294, "quantity": 2}, {"sku": "WB-H098", "name": "Water Bottle - 30 oz.", "price": 2.994, "quantity": 5}, {"sku": "BK-R79Y-40", "name": "Road-350-W Yellow, 40", "price": 1020.594, "quantity": 1}, {"sku": "BK-R19B-58", "name": "Road-750 Black, 58", "price": 323.994, "quantity": 3}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.994, "quantity": 1}, {"sku": "GL-H102-M", "name": "Half-Finger Gloves, M", "price": 14.694, "quantity": 4}, {"sku": "SJ-0194-X", "name": "Short-Sleeve Classic Jersey, XL", "price": 32.394, "quantity": 4}, {"sku": "BK-R89B-44", "name": "Road-250 Black, 44", "price": 1466.01, "quantity": 5}, {"sku": "BK-R89R-58", "name": "Road-250 Red, 58", "price": 1466.01, "quantity": 1}, {"sku": "PD-R853", "name": "HL Road Pedal", "price": 48.594, "quantity": 1}, {"sku": "PD-R563", "name": "ML Road Pedal", "price": 37.254, "quantity": 4}, {"sku": "BK-R89B-58", "name": "Road-250 Black, 58", "price": 1466.01, "quantity": 4}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.394, "quantity": 4}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 5.394, "quantity": 7}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 29.994, "quantity": 3}, {"sku": "VE-C304-S", "name": "Classic Vest, S", "price": 36.83, "quantity": 13}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 29.994, "quantity": 2}]}
# content:  {"_id": "0288E4FA-1C89-411E-801E-5098B0CDC414", "customerId": "537E369C-C65B-4F23-B7C0-D07DFFFAC08B", "orderDate": "2013-11-03 00:00:00", "shipDate": "2013-11-10 00:00:00", "details": [{"sku": "TT-T092", "name": "Touring Tire Tube", "price": 4.99, "quantity": 1}, {"sku": "PK-7098", "name": "Patch Kit/8 Patches", "price": 2.29, "quantity": 1}]}
# content:  {"_id": "029E366C-0023-40AB-9684-51F8BC734BCB", "customerId": "022BB1FA-35E6-4CC5-9079-8EA61FE7FAAE", "orderDate": "2013-02-28 00:00:00", "shipDate": "2013-03-07 00:00:00", "details": [{"sku": "GL-F110-M", "name": "Full-Finger Gloves, M", "price": 22.794, "quantity": 2}, {"sku": "GL-F110-S", "name": "Full-Finger Gloves, S", "price": 22.794, "quantity": 1}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 6}, {"sku": "BK-M68B-38", "name": "Mountain-200 Black, 38", "price": 1229.4589, "quantity": 1}, {"sku": "GL-F110-L", "name": "Full-Finger Gloves, L", "price": 22.794, "quantity": 3}, {"sku": "TG-W091-L", "name": "Women's Tights, L", "price": 44.994, "quantity": 2}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 1}]}
# content:  {"_id": "0379883C-C865-4D57-BF65-AF79267CE961", "customerId": "29C95F8A-9C52-48DB-A1C4-8A14C430FF06", "orderDate": "2012-01-01 00:00:00", "shipDate": "2012-01-08 00:00:00", "details": [{"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 10}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.1865, "quantity": 6}, {"sku": "BK-R68R-58", "name": "Road-450 Red, 58", "price": 874.794, "quantity": 4}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 9}, {"sku": "FR-R38R-60", "name": "LL Road Frame - Red, 60", "price": 183.9382, "quantity": 5}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.1865, "quantity": 3}, {"sku": "BK-R68R-44", "name": "Road-450 Red, 44", "price": 874.794, "quantity": 3}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 28.8404, "quantity": 4}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 3}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 178.5808, "quantity": 1}, {"sku": "BK-R50B-60", "name": "Road-650 Black, 60", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 5}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 28.8404, "quantity": 9}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.0136, "quantity": 11}, {"sku": "FR-R38R-44", "name": "LL Road Frame - Red, 44", "price": 183.9382, "quantity": 1}, {"sku": "BK-R68R-60", "name": "Road-450 Red, 60", "price": 874.794, "quantity": 1}, {"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 4}, {"sku": "BK-R93R-56", "name": "Road-150 Red, 56", "price": 2146.962, "quantity": 2}, {"sku": "FR-R72R-48", "name": "ML Road Frame - Red, 48", "price": 356.898, "quantity": 4}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 7}, {"sku": "BK-R50B-44", "name": "Road-650 Black, 44", "price": 419.4589, "quantity": 1}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.1865, "quantity": 4}, {"sku": "BK-R50R-52", "name": "Road-650 Red, 52", "price": 419.4589, "quantity": 6}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 7}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 5}]}
# content:  {"_id": "039896DA-698A-4C60-8A6B-083926A5C281", "customerId": "ED5B6EC1-79B6-4902-B325-F9A900854022", "orderDate": "2014-02-22 00:00:00", "shipDate": "2014-03-01 00:00:00", "details": [{"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 34.99, "quantity": 1}, {"sku": "TT-T092", "name": "Touring Tire Tube", "price": 4.99, "quantity": 1}]}
# content:  {"_id": "04B0E36F-E776-4B93-89A2-3FDD59B4F0B5", "customerId": "D01E483D-AEE0-41E6-A2E1-0220AA233A7A", "orderDate": "2014-05-06 00:00:00", "shipDate": "2014-05-13 00:00:00", "details": [{"sku": "SH-W890-M", "name": "Women's Mountain Shorts, M", "price": 69.99, "quantity": 1}, {"sku": "GL-H102-S", "name": "Half-Finger Gloves, S", "price": 24.49, "quantity": 1}]}
# content:  {"_id": "082CC387-8847-4F7C-BB32-C5FC773D4AE0", "customerId": "7688FC05-6780-428D-AFD9-0F0639EA7148", "orderDate": "2013-08-31 00:00:00", "shipDate": "2013-09-07 00:00:00", "details": [{"sku": "TT-M928", "name": "Mountain Tire Tube", "price": 4.99, "quantity": 1}, {"sku": "TI-M823", "name": "HL Mountain Tire", "price": 35.0, "quantity": 1}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 34.99, "quantity": 1}]}
# content:  {"_id": "15DF138D-BE82-41B8-A7C1-48D5751A8589", "customerId": "6DF10977-EA10-4607-AF0F-74EDABA54943", "orderDate": "2011-10-01 00:00:00", "shipDate": "2011-10-08 00:00:00", "details": [{"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 2}]}
# content:  {"_id": "05223D68-4D04-4EF3-A4E2-BE7DEA6A8066", "customerId": "9092EEDE-9BE8-4E85-B017-A243C291173E", "orderDate": "2013-07-31 00:00:00", "shipDate": "2013-08-07 00:00:00", "details": [{"sku": "BK-R79Y-48", "name": "Road-350-W Yellow, 48", "price": 1020.594, "quantity": 4}, {"sku": "CL-9009", "name": "Bike Wash - Dissolver", "price": 4.77, "quantity": 3}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.994, "quantity": 5}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 202.332, "quantity": 1}, {"sku": "GL-H102-M", "name": "Half-Finger Gloves, M", "price": 14.694, "quantity": 3}, {"sku": "PD-R853", "name": "HL Road Pedal", "price": 48.594, "quantity": 3}, {"sku": "PD-R563", "name": "ML Road Pedal", "price": 37.254, "quantity": 2}, {"sku": "VE-C304-S", "name": "Classic Vest, S", "price": 38.1, "quantity": 6}, {"sku": "SJ-0194-X", "name": "Short-Sleeve Classic Jersey, XL", "price": 32.394, "quantity": 6}, {"sku": "PD-R347", "name": "LL Road Pedal", "price": 24.294, "quantity": 3}, {"sku": "SJ-0194-S", "name": "Short-Sleeve Classic Jersey, S", "price": 32.394, "quantity": 4}, {"sku": "FR-R72Y-44", "name": "ML Road Frame-W - Yellow, 44", "price": 356.898, "quantity": 1}, {"sku": "RA-H123", "name": "Hitch Rack - 4-Bike", "price": 72.0, "quantity": 2}, {"sku": "HY-1023-70", "name": "Hydration Pack - 70 oz.", "price": 32.994, "quantity": 5}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 29.994, "quantity": 3}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 29.994, "quantity": 1}, {"sku": "BK-R19B-52", "name": "Road-750 Black, 52", "price": 323.994, "quantity": 2}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.394, "quantity": 3}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.994, "quantity": 4}, {"sku": "SJ-0194-L", "name": "Short-Sleeve Classic Jersey, L", "price": 32.394, "quantity": 6}, {"sku": "WB-H098", "name": "Water Bottle - 30 oz.", "price": 2.994, "quantity": 4}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 4.9445, "quantity": 22}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.994, "quantity": 4}, {"sku": "BK-R79Y-40", "name": "Road-350-W Yellow, 40", "price": 1020.594, "quantity": 4}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 3}, {"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.2142, "quantity": 14}, {"sku": "VE-C304-M", "name": "Classic Vest, M", "price": 38.1, "quantity": 2}]}
# content:  {"_id": "05F826D9-3526-463D-96CE-A2340DE8E554", "customerId": "29C95F8A-9C52-48DB-A1C4-8A14C430FF06", "orderDate": "2012-03-30 00:00:00", "shipDate": "2012-04-06 00:00:00", "details": [{"sku": "BK-R50B-44", "name": "Road-650 Black, 44", "price": 419.4589, "quantity": 2}, {"sku": "FR-R38R-44", "name": "LL Road Frame - Red, 44", "price": 183.9382, "quantity": 3}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 2}, {"sku": "BK-R93R-62", "name": "Road-150 Red, 62", "price": 2146.962, "quantity": 1}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 28.8404, "quantity": 8}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.1865, "quantity": 7}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 28.8404, "quantity": 8}, {"sku": "BK-R68R-60", "name": "Road-450 Red, 60", "price": 874.794, "quantity": 5}, {"sku": "BK-R68R-58", "name": "Road-450 Red, 58", "price": 874.794, "quantity": 4}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 4.7543, "quantity": 16}, {"sku": "BK-R50R-52", "name": "Road-650 Red, 52", "price": 419.4589, "quantity": 1}, {"sku": "FR-R72R-48", "name": "ML Road Frame - Red, 48", "price": 356.898, "quantity": 3}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 2}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 5}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 8}, {"sku": "FR-R38R-48", "name": "LL Road Frame - Red, 48", "price": 183.9382, "quantity": 1}, {"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 4}, {"sku": "BK-R50B-60", "name": "Road-650 Black, 60", "price": 419.4589, "quantity": 1}, {"sku": "BK-R93R-56", "name": "Road-150 Red, 56", "price": 2146.962, "quantity": 8}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.1865, "quantity": 7}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 4}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 27.879, "quantity": 13}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 19.5136, "quantity": 13}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 178.5808, "quantity": 4}, {"sku": "FR-R72R-52", "name": "ML Road Frame - Red, 52", "price": 356.898, "quantity": 4}, {"sku": "BK-R68R-44", "name": "Road-450 Red, 44", "price": 874.794, "quantity": 2}, {"sku": "FR-R38R-62", "name": "LL Road Frame - Red, 62", "price": 183.9382, "quantity": 5}, {"sku": "FR-R38R-60", "name": "LL Road Frame - Red, 60", "price": 183.9382, "quantity": 6}]}
# content:  {"_id": "06794E40-1A3E-49B6-9914-94438A2D8813", "customerId": "44A6D5F6-AF44-4B34-8AB5-21C5DC50926E", "orderDate": "2014-03-30 00:00:00", "shipDate": "2014-04-06 00:00:00", "details": [{"sku": "TI-R982", "name": "HL Road Tire", "price": 32.6, "quantity": 1}, {"sku": "TT-R982", "name": "Road Tire Tube", "price": 3.99, "quantity": 1}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 34.99, "quantity": 1}]}
# content:  {"_id": "06C02E4F-484B-48AF-8C97-B952FF4E1313", "customerId": "6325847B-D85C-4F23-9C47-7346082D38A1", "orderDate": "2013-07-31 00:00:00", "shipDate": "2013-08-07 00:00:00", "details": [{"sku": "BK-M68B-38", "name": "Mountain-200 Black, 38", "price": 1376.994, "quantity": 4}, {"sku": "SE-M940", "name": "HL Mountain Seat/Saddle", "price": 31.584, "quantity": 6}, {"sku": "PD-M562", "name": "HL Mountain Pedal", "price": 48.594, "quantity": 2}, {"sku": "SH-W890-M", "name": "Women's Mountain Shorts, M", "price": 41.994, "quantity": 10}, {"sku": "HB-M763", "name": "ML Mountain Handlebars", "price": 37.152, "quantity": 3}, {"sku": "PD-M282", "name": "LL Mountain Pedal", "price": 24.294, "quantity": 1}, {"sku": "SH-W890-S", "name": "Women's Mountain Shorts, S", "price": 41.994, "quantity": 7}, {"sku": "SH-W890-L", "name": "Women's Mountain Shorts, L", "price": 41.994, "quantity": 3}]}
# content:  {"_id": "06CA14C2-29D5-4306-B9D1-8E804C358494", "customerId": "D6A5D690-7A0C-42F4-8557-B1FE8326795F", "orderDate": "2011-12-01 00:00:00", "shipDate": "2011-12-08 00:00:00", "details": [{"sku": "BK-R50R-52", "name": "Road-650 Red, 52", "price": 419.4589, "quantity": 2}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 2}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 3}, {"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 1}, {"sku": "BK-R68R-60", "name": "Road-450 Red, 60", "price": 874.794, "quantity": 2}, {"sku": "BK-R68R-48", "name": "Road-450 Red, 48", "price": 874.794, "quantity": 1}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 1}, {"sku": "BK-R93R-62", "name": "Road-150 Red, 62", "price": 2146.962, "quantity": 5}, {"sku": "BK-R93R-48", "name": "Road-150 Red, 48", "price": 2146.962, "quantity": 2}, {"sku": "BK-R50B-60", "name": "Road-650 Black, 60", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50B-62", "name": "Road-650 Black, 62", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50B-48", "name": "Road-650 Black, 48", "price": 419.4589, "quantity": 1}, {"sku": "BK-R93R-44", "name": "Road-150 Red, 44", "price": 2146.962, "quantity": 2}, {"sku": "BK-R50B-44", "name": "Road-650 Black, 44", "price": 419.4589, "quantity": 2}, {"sku": "BK-R93R-56", "name": "Road-150 Red, 56", "price": 2146.962, "quantity": 1}]}
# content:  {"_id": "06FE91D2-B350-471A-AD29-906BF4EB97C4", "customerId": "D133397E-83ED-4FF3-BD44-62D7481237B2", "orderDate": "2011-07-01 00:00:00", "shipDate": "2011-07-08 00:00:00", "details": [{"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 1}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 1}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 1}]}
# content:  {"_id": "074853E3-5AD9-4708-A6CD-FA9745B51839", "customerId": "E2094914-6C88-44CC-B5F4-AA4FB78C2710", "orderDate": "2014-04-15 00:00:00", "shipDate": "2014-04-22 00:00:00", "details": [{"sku": "TI-T723", "name": "Touring Tire", "price": 28.99, "quantity": 1}, {"sku": "TT-T092", "name": "Touring Tire Tube", "price": 4.99, "quantity": 1}]}
# content:  {"_id": "07A6A1AB-D908-412F-A7C0-204FDD0807BE", "customerId": "F5E9C71A-DA28-4F43-9512-825C3AD94528", "orderDate": "2013-06-30 00:00:00", "shipDate": "2013-07-07 00:00:00", "details": [{"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.994, "quantity": 4}, {"sku": "HY-1023-70", "name": "Hydration Pack - 70 oz.", "price": 32.994, "quantity": 3}, {"sku": "VE-C304-M", "name": "Classic Vest, M", "price": 38.1, "quantity": 4}, {"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.394, "quantity": 2}, {"sku": "RA-H123", "name": "Hitch Rack - 4-Bike", "price": 72.0, "quantity": 4}, {"sku": "VE-C304-S", "name": "Classic Vest, S", "price": 38.1, "quantity": 3}, {"sku": "WB-H098", "name": "Water Bottle - 30 oz.", "price": 2.994, "quantity": 5}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 3}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 29.994, "quantity": 8}, {"sku": "GL-H102-M", "name": "Half-Finger Gloves, M", "price": 14.694, "quantity": 5}, {"sku": "SJ-0194-L", "name": "Short-Sleeve Classic Jersey, L", "price": 32.394, "quantity": 5}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 202.332, "quantity": 6}, {"sku": "BK-R79Y-40", "name": "Road-350-W Yellow, 40", "price": 1020.594, "quantity": 3}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.994, "quantity": 5}, {"sku": "PD-R347", "name": "LL Road Pedal", "price": 24.294, "quantity": 2}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.994, "quantity": 2}, {"sku": "PD-R853", "name": "HL Road Pedal", "price": 48.594, "quantity": 3}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 5.2142, "quantity": 12}, {"sku": "SJ-0194-X", "name": "Short-Sleeve Classic Jersey, XL", "price": 32.394, "quantity": 2}, {"sku": "FR-R72Y-44", "name": "ML Road Frame-W - Yellow, 44", "price": 356.898, "quantity": 7}, {"sku": "BK-R79Y-48", "name": "Road-350-W Yellow, 48", "price": 1020.594, "quantity": 1}, {"sku": "PD-R563", "name": "ML Road Pedal", "price": 37.254, "quantity": 3}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.394, "quantity": 2}]}
# content:  {"_id": "0BD1E390-D1F4-46A6-8180-60696A44A01E", "customerId": "4FEAA310-61D4-4A89-8E78-3CA6B34F7934", "orderDate": "2012-03-30 00:00:00", "shipDate": "2012-04-06 00:00:00", "details": [{"sku": "SO-B909-M", "name": "Mountain Bike Socks, M", "price": 5.7, "quantity": 6}, {"sku": "BK-M82S-38", "name": "Mountain-100 Silver, 38", "price": 2039.994, "quantity": 6}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 2}, {"sku": "BK-M82S-42", "name": "Mountain-100 Silver, 42", "price": 2039.994, "quantity": 7}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.1865, "quantity": 5}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.1865, "quantity": 2}, {"sku": "BK-M82S-44", "name": "Mountain-100 Silver, 44", "price": 2039.994, "quantity": 2}, {"sku": "FR-M94B-42", "name": "HL Mountain Frame - Black, 42", "price": 714.7043, "quantity": 2}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 28.8404, "quantity": 3}, {"sku": "BK-M82B-44", "name": "Mountain-100 Black, 44", "price": 2024.994, "quantity": 5}, {"sku": "BK-M82S-48", "name": "Mountain-100 Silver, 48", "price": 2039.994, "quantity": 5}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 6}, {"sku": "BK-M82B-38", "name": "Mountain-100 Black, 38", "price": 2024.994, "quantity": 6}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.1865, "quantity": 4}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 28.8404, "quantity": 5}, {"sku": "BK-M82B-48", "name": "Mountain-100 Black, 48", "price": 2024.994, "quantity": 4}, {"sku": "FR-M94S-38", "name": "HL Mountain Frame - Silver, 38", "price": 722.5949, "quantity": 2}]}
# content:  {"_id": "0C6F0AF7-7F05-4CF2-A2BB-221557666635", "customerId": "670C1D45-DCAF-4B08-8358-F1DFBAE8E8C8", "orderDate": "2011-10-01 00:00:00", "shipDate": "2011-10-08 00:00:00", "details": [{"sku": "SO-B909-L", "name": "Mountain Bike Socks, L", "price": 5.7, "quantity": 1}, {"sku": "SO-B909-M", "name": "Mountain Bike Socks, M", "price": 5.7, "quantity": 6}, {"sku": "BK-M82S-48", "name": "Mountain-100 Silver, 48", "price": 2039.994, "quantity": 2}, {"sku": "BK-M82B-44", "name": "Mountain-100 Black, 44", "price": 2024.994, "quantity": 1}, {"sku": "BK-M82S-38", "name": "Mountain-100 Silver, 38", "price": 2039.994, "quantity": 1}]}
# content:  {"_id": "0CC855B1-8DD6-48EB-98E6-CC623563681D", "customerId": "8B0C1168-28E6-4F0D-82FB-C53123F76280", "orderDate": "2014-01-29 00:00:00", "shipDate": "2014-02-05 00:00:00", "details": [{"sku": "BK-R79Y-48", "name": "Road-350-W Yellow, 48", "price": 1020.594, "quantity": 6}, {"sku": "BK-R19B-44", "name": "Road-750 Black, 44", "price": 323.994, "quantity": 2}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 5.2142, "quantity": 12}, {"sku": "BK-R64Y-44", "name": "Road-550-W Yellow, 44", "price": 672.294, "quantity": 3}, {"sku": "BK-R79Y-42", "name": "Road-350-W Yellow, 42", "price": 1020.594, "quantity": 6}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.994, "quantity": 3}, {"sku": "BK-R19B-58", "name": "Road-750 Black, 58", "price": 323.994, "quantity": 3}, {"sku": "BK-R89B-44", "name": "Road-250 Black, 44", "price": 1466.01, "quantity": 3}, {"sku": "HY-1023-70", "name": "Hydration Pack - 70 oz.", "price": 32.994, "quantity": 4}, {"sku": "BK-R79Y-40", "name": "Road-350-W Yellow, 40", "price": 1020.594, "quantity": 6}, {"sku": "PD-R347", "name": "LL Road Pedal", "price": 24.294, "quantity": 5}, {"sku": "BK-R64Y-38", "name": "Road-550-W Yellow, 38", "price": 672.294, "quantity": 3}, {"sku": "BK-R89B-58", "name": "Road-250 Black, 58", "price": 1466.01, "quantity": 5}, {"sku": "BK-R19B-52", "name": "Road-750 Black, 52", "price": 323.994, "quantity": 2}, {"sku": "BK-R89B-52", "name": "Road-250 Black, 52", "price": 1466.01, "quantity": 8}, {"sku": "BK-R64Y-48", "name": "Road-550-W Yellow, 48", "price": 672.294, "quantity": 4}, {"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.394, "quantity": 5}, {"sku": "VE-C304-M", "name": "Classic Vest, M", "price": 38.1, "quantity": 2}, {"sku": "BK-R89R-58", "name": "Road-250 Red, 58", "price": 1466.01, "quantity": 2}, {"sku": "PD-R563", "name": "ML Road Pedal", "price": 37.254, "quantity": 4}, {"sku": "PD-R853", "name": "HL Road Pedal", "price": 48.594, "quantity": 2}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 3}, {"sku": "BK-R89B-48", "name": "Road-250 Black, 48", "price": 1466.01, "quantity": 3}, {"sku": "BK-R64Y-42", "name": "Road-550-W Yellow, 42", "price": 672.294, "quantity": 1}, {"sku": "BK-R79Y-44", "name": "Road-350-W Yellow, 44", "price": 1020.594, "quantity": 5}]}
# content:  {"_id": "0D7702D7-D28E-4AAC-BCE8-D97E684BABBB", "customerId": "E2094914-6C88-44CC-B5F4-AA4FB78C2710", "orderDate": "2014-06-05 00:00:00", "shipDate": "2014-06-12 00:00:00", "details": [{"sku": "TT-R982", "name": "Road Tire Tube", "price": 3.99, "quantity": 1}, {"sku": "TI-R982", "name": "HL Road Tire", "price": 32.6, "quantity": 1}, {"sku": "PK-7098", "name": "Patch Kit/8 Patches", "price": 2.29, "quantity": 1}]}
# content:  {"_id": "0D861644-5CB6-40C4-9C8A-162C6C7A7769", "customerId": "7688FC05-6780-428D-AFD9-0F0639EA7148", "orderDate": "2013-10-04 00:00:00", "shipDate": "2013-10-11 00:00:00", "details": [{"sku": "TI-R628", "name": "ML Road Tire", "price": 24.99, "quantity": 1}]}
# content:  {"_id": "0E11BB4E-EC2F-44E1-A13D-567D0BF45A0C", "customerId": "D133397E-83ED-4FF3-BD44-62D7481237B2", "orderDate": "2013-12-31 00:00:00", "shipDate": "2014-01-07 00:00:00", "details": [{"sku": "SJ-0194-X", "name": "Short-Sleeve Classic Jersey, XL", "price": 32.394, "quantity": 1}, {"sku": "BK-R64Y-48", "name": "Road-550-W Yellow, 48", "price": 672.294, "quantity": 1}, {"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.394, "quantity": 3}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 5.394, "quantity": 2}, {"sku": "VE-C304-S", "name": "Classic Vest, S", "price": 38.1, "quantity": 2}, {"sku": "BK-R79Y-40", "name": "Road-350-W Yellow, 40", "price": 1020.594, "quantity": 4}, {"sku": "BK-R64Y-38", "name": "Road-550-W Yellow, 38", "price": 672.294, "quantity": 3}, {"sku": "BK-R19B-52", "name": "Road-750 Black, 52", "price": 323.994, "quantity": 1}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 2}]}
# content:  {"_id": "0E173416-B79C-4940-B335-33DD7837D5B9", "customerId": "E2094914-6C88-44CC-B5F4-AA4FB78C2710", "orderDate": "2013-07-11 00:00:00", "shipDate": "2013-07-18 00:00:00", "details": [{"sku": "TT-R982", "name": "Road Tire Tube", "price": 3.99, "quantity": 1}, {"sku": "PK-7098", "name": "Patch Kit/8 Patches", "price": 2.29, "quantity": 1}, {"sku": "TI-R628", "name": "ML Road Tire", "price": 24.99, "quantity": 1}, {"sku": "CL-9009", "name": "Bike Wash - Dissolver", "price": 7.95, "quantity": 1}]}
# content:  {"_id": "0EAC39C8-C0E7-43F0-AEE0-48439B0591C1", "customerId": "44A6D5F6-AF44-4B34-8AB5-21C5DC50926E", "orderDate": "2014-06-10 00:00:00", "shipDate": "2014-06-17 00:00:00", "details": [{"sku": "TT-R982", "name": "Road Tire Tube", "price": 3.99, "quantity": 1}, {"sku": "TI-R628", "name": "ML Road Tire", "price": 24.99, "quantity": 1}]}
# content:  {"_id": "0F81794C-B0C5-4644-AE64-E5EDF4374A06", "customerId": "ED0B129D-4B38-4E1F-B404-18FA2B68944D", "orderDate": "2013-10-30 00:00:00", "shipDate": "2013-11-06 00:00:00", "details": [{"sku": "SO-R809-M", "name": "Racing Socks, M", "price": 5.394, "quantity": 3}, {"sku": "BK-R79Y-40", "name": "Road-350-W Yellow, 40", "price": 1020.594, "quantity": 1}, {"sku": "SO-R809-L", "name": "Racing Socks, L", "price": 5.394, "quantity": 8}, {"sku": "BK-R79Y-48", "name": "Road-350-W Yellow, 48", "price": 1020.594, "quantity": 1}, {"sku": "BK-R19B-48", "name": "Road-750 Black, 48", "price": 323.994, "quantity": 2}]}
# content:  {"_id": "104FB645-0C6B-40D5-B517-D0D321F1C00E", "customerId": "9092EEDE-9BE8-4E85-B017-A243C291173E", "orderDate": "2012-04-30 00:00:00", "shipDate": "2012-05-07 00:00:00", "details": [{"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 1}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 3}, {"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 2}, {"sku": "BK-R68R-58", "name": "Road-450 Red, 58", "price": 874.794, "quantity": 1}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 2}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 1}]}
# content:  {"_id": "10F3E6D9-D451-45F0-9B55-49E32CF360AB", "customerId": "34E7A125-0F66-4673-A80B-20B4C46EAD3A", "orderDate": "2011-12-01 00:00:00", "shipDate": "2011-12-08 00:00:00", "details": [{"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50R-58", "name": "Road-650 Red, 58", "price": 419.4589, "quantity": 3}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 2}, {"sku": "BK-R50R-52", "name": "Road-650 Red, 52", "price": 419.4589, "quantity": 1}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 2}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 1}, {"sku": "BK-R68R-48", "name": "Road-450 Red, 48", "price": 874.794, "quantity": 1}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 1}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 1}, {"sku": "BK-R68R-58", "name": "Road-450 Red, 58", "price": 874.794, "quantity": 2}, {"sku": "BK-R50B-48", "name": "Road-650 Black, 48", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50B-60", "name": "Road-650 Black, 60", "price": 419.4589, "quantity": 1}, {"sku": "BK-R68R-44", "name": "Road-450 Red, 44", "price": 874.794, "quantity": 2}, {"sku": "BK-R93R-56", "name": "Road-150 Red, 56", "price": 2146.962, "quantity": 1}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 5}, {"sku": "BK-R93R-44", "name": "Road-150 Red, 44", "price": 2146.962, "quantity": 2}]}
# content:  {"_id": "11C363FB-14D7-4BB3-AD1A-2AA215040096", "customerId": "C13244AB-0B74-4466-985D-BA1C1731968C", "orderDate": "2011-08-31 00:00:00", "shipDate": "2011-09-07 00:00:00", "details": [{"sku": "FR-R38B-58", "name": "LL Road Frame - Black, 58", "price": 178.5808, "quantity": 4}, {"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 4}, {"sku": "FR-R38R-44", "name": "LL Road Frame - Red, 44", "price": 183.9382, "quantity": 2}, {"sku": "BK-R93R-56", "name": "Road-150 Red, 56", "price": 2146.962, "quantity": 5}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 3}, {"sku": "FR-R72R-48", "name": "ML Road Frame - Red, 48", "price": 356.898, "quantity": 1}, {"sku": "BK-R50B-48", "name": "Road-650 Black, 48", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 4}, {"sku": "BK-R93R-62", "name": "Road-150 Red, 62", "price": 2146.962, "quantity": 3}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 178.5808, "quantity": 4}, {"sku": "FR-R92R-62", "name": "HL Road Frame - Red, 62", "price": 758.0759, "quantity": 2}, {"sku": "FR-R38R-48", "name": "LL Road Frame - Red, 48", "price": 183.9382, "quantity": 1}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 10}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 3}, {"sku": "FR-R92R-44", "name": "HL Road Frame - Red, 44", "price": 758.0759, "quantity": 1}, {"sku": "BK-R50B-60", "name": "Road-650 Black, 60", "price": 419.4589, "quantity": 4}, {"sku": "BK-R50B-44", "name": "Road-650 Black, 44", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50B-62", "name": "Road-650 Black, 62", "price": 419.4589, "quantity": 2}, {"sku": "FR-R72R-52", "name": "ML Road Frame - Red, 52", "price": 356.898, "quantity": 1}, {"sku": "BK-R68R-60", "name": "Road-450 Red, 60", "price": 874.794, "quantity": 2}, {"sku": "BK-R68R-44", "name": "Road-450 Red, 44", "price": 874.794, "quantity": 3}, {"sku": "FR-R38R-60", "name": "LL Road Frame - Red, 60", "price": 183.9382, "quantity": 1}, {"sku": "FR-R38B-44", "name": "LL Road Frame - Black, 44", "price": 178.5808, "quantity": 1}]}
# content:  {"_id": "13907604-2EBF-424B-8CFA-29196FC62E85", "customerId": "6325847B-D85C-4F23-9C47-7346082D38A1", "orderDate": "2013-10-30 00:00:00", "shipDate": "2013-11-06 00:00:00", "details": [{"sku": "SH-W890-M", "name": "Women's Mountain Shorts, M", "price": 41.994, "quantity": 2}, {"sku": "SH-W890-S", "name": "Women's Mountain Shorts, S", "price": 41.994, "quantity": 9}, {"sku": "SH-W890-L", "name": "Women's Mountain Shorts, L", "price": 41.994, "quantity": 6}, {"sku": "BK-M68B-38", "name": "Mountain-200 Black, 38", "price": 1376.994, "quantity": 2}, {"sku": "BK-M68B-42", "name": "Mountain-200 Black, 42", "price": 1376.994, "quantity": 2}]}
# content:  {"_id": "139E3E95-212B-4E38-8468-5FFF4853C535", "customerId": "6A0B9894-8EDB-4568-A4AC-03241F72F62C", "orderDate": "2011-08-31 00:00:00", "shipDate": "2011-09-07 00:00:00", "details": [{"sku": "BK-M82B-38", "name": "Mountain-100 Black, 38", "price": 2024.994, "quantity": 8}, {"sku": "FR-M94B-44", "name": "HL Mountain Frame - Black, 44", "price": 809.76, "quantity": 1}, {"sku": "FR-M94S-46", "name": "HL Mountain Frame - Silver, 46", "price": 722.5949, "quantity": 2}, {"sku": "BK-M82S-42", "name": "Mountain-100 Silver, 42", "price": 2039.994, "quantity": 2}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 6}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.1865, "quantity": 2}, {"sku": "FR-M94B-42", "name": "HL Mountain Frame - Black, 42", "price": 714.7043, "quantity": 1}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.1865, "quantity": 3}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 28.8404, "quantity": 3}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 28.8404, "quantity": 4}, {"sku": "FR-M94S-42", "name": "HL Mountain Frame - Silver, 42", "price": 722.5949, "quantity": 2}, {"sku": "FR-M94B-48", "name": "HL Mountain Frame - Black, 48", "price": 809.76, "quantity": 1}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.1865, "quantity": 4}, {"sku": "BK-M82S-38", "name": "Mountain-100 Silver, 38", "price": 2039.994, "quantity": 3}, {"sku": "BK-M82S-44", "name": "Mountain-100 Silver, 44", "price": 2039.994, "quantity": 4}]}
# content:  {"_id": "13BBA20F-464C-4088-A02D-6FA115080305", "customerId": "D01E483D-AEE0-41E6-A2E1-0220AA233A7A", "orderDate": "2013-09-22 00:00:00", "shipDate": "2013-09-29 00:00:00", "details": [{"sku": "TI-T723", "name": "Touring Tire", "price": 28.99, "quantity": 1}]}
# content:  {"_id": "14C67ECD-0A6C-4154-92C7-FCA34CA785AB", "customerId": "8B0C1168-28E6-4F0D-82FB-C53123F76280", "orderDate": "2011-08-01 00:00:00", "shipDate": "2011-08-08 00:00:00", "details": [{"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.1865, "quantity": 4}, {"sku": "FR-R38R-44", "name": "LL Road Frame - Red, 44", "price": 183.9382, "quantity": 2}, {"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50B-60", "name": "Road-650 Black, 60", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 3}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 1}, {"sku": "FR-R38R-60", "name": "LL Road Frame - Red, 60", "price": 183.9382, "quantity": 3}, {"sku": "BK-R50B-44", "name": "Road-650 Black, 44", "price": 419.4589, "quantity": 1}, {"sku": "BK-R93R-56", "name": "Road-150 Red, 56", "price": 2146.962, "quantity": 4}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 2}, {"sku": "FR-R72R-48", "name": "ML Road Frame - Red, 48", "price": 356.898, "quantity": 1}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 1}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 3}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 28.8404, "quantity": 2}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.1865, "quantity": 4}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.1865, "quantity": 3}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 178.5808, "quantity": 1}, {"sku": "BK-R68R-60", "name": "Road-450 Red, 60", "price": 874.794, "quantity": 2}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 2}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 1}, {"sku": "BK-R68R-58", "name": "Road-450 Red, 58", "price": 874.794, "quantity": 3}]}
# content:  {"_id": "155FB7B1-197F-4A9E-BE5A-15462E4CAC5A", "customerId": "6325847B-D85C-4F23-9C47-7346082D38A1", "orderDate": "2014-05-01 00:00:00", "shipDate": "2014-05-08 00:00:00", "details": [{"sku": "SH-W890-L", "name": "Women's Mountain Shorts, L", "price": 41.994, "quantity": 8}, {"sku": "BK-M68B-38", "name": "Mountain-200 Black, 38", "price": 1376.994, "quantity": 4}, {"sku": "SH-W890-M", "name": "Women's Mountain Shorts, M", "price": 41.994, "quantity": 3}, {"sku": "SH-W890-S", "name": "Women's Mountain Shorts, S", "price": 41.994, "quantity": 5}]}
# content:  {"_id": "1599E6D3-A707-4D16-9942-0DC531C73106", "customerId": "D133397E-83ED-4FF3-BD44-62D7481237B2", "orderDate": "2011-10-01 00:00:00", "shipDate": "2011-10-08 00:00:00", "details": [{"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 2}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 1}, {"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 2}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 1}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 1}]}
# content:  {"_id": "160E7D05-8D2F-4384-B1C0-E4EEA83FEB4A", "customerId": "0E57A241-1B95-43A2-BCFB-637608B0AD1A", "orderDate": "2013-07-22 00:00:00", "shipDate": "2013-07-29 00:00:00", "details": [{"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 34.99, "quantity": 1}]}
# content:  {"_id": "16DA6D4B-A880-4D30-A548-13F1FFB12410", "customerId": "022BB1FA-35E6-4CC5-9079-8EA61FE7FAAE", "orderDate": "2011-05-31 00:00:00", "shipDate": "2011-06-07 00:00:00", "details": [{"sku": "SO-B909-M", "name": "Mountain Bike Socks, M", "price": 5.7, "quantity": 4}, {"sku": "SO-B909-L", "name": "Mountain Bike Socks, L", "price": 5.7, "quantity": 1}, {"sku": "BK-M82B-38", "name": "Mountain-100 Black, 38", "price": 2024.994, "quantity": 3}, {"sku": "BK-M82B-48", "name": "Mountain-100 Black, 48", "price": 2024.994, "quantity": 2}, {"sku": "BK-M82B-42", "name": "Mountain-100 Black, 42", "price": 2024.994, "quantity": 2}]}
# ...
# content:  {"_id": "3330FAC1-B317-4389-86F9-38FCCE7DA8C0", "customerId": "91A01FF7-B425-4A9F-B2F4-E4285E1D78AE", "orderDate": "2013-03-30 00:00:00", "shipDate": "2013-04-06 00:00:00", "details": [{"sku": "GL-F110-S", "name": "Full-Finger Gloves, S", "price": 22.794, "quantity": 2}, {"sku": "GL-F110-L", "name": "Full-Finger Gloves, L", "price": 22.794, "quantity": 2}, {"sku": "BK-M68S-38", "name": "Mountain-200 Silver, 38", "price": 1242.8518, "quantity": 1}, {"sku": "BK-M68B-38", "name": "Mountain-200 Black, 38", "price": 1229.4589, "quantity": 1}, {"sku": "BK-M68B-42", "name": "Mountain-200 Black, 42", "price": 1229.4589, "quantity": 1}]}
# content:  {"_id": "33C72C17-9BB0-4782-B3CC-B2A3443D03B7", "customerId": "E2094914-6C88-44CC-B5F4-AA4FB78C2710", "orderDate": "2013-12-21 00:00:00", "shipDate": "2013-12-28 00:00:00", "details": [{"sku": "TI-R628", "name": "ML Road Tire", "price": 24.99, "quantity": 1}, {"sku": "PK-7098", "name": "Patch Kit/8 Patches", "price": 2.29, "quantity": 1}, {"sku": "TT-R982", "name": "Road Tire Tube", "price": 3.99, "quantity": 1}]}
# content:  {"_id": "35C44C3D-5179-4182-8A94-F6929A5673A9", "customerId": "6325847B-D85C-4F23-9C47-7346082D38A1", "orderDate": "2013-04-30 00:00:00", "shipDate": "2013-05-07 00:00:00", "details": [{"sku": "BK-M68B-38", "name": "Mountain-200 Black, 38", "price": 1229.4589, "quantity": 4}, {"sku": "GL-F110-M", "name": "Full-Finger Gloves, M", "price": 22.794, "quantity": 8}, {"sku": "GL-F110-S", "name": "Full-Finger Gloves, S", "price": 22.794, "quantity": 1}, {"sku": "GL-F110-L", "name": "Full-Finger Gloves, L", "price": 22.794, "quantity": 6}, {"sku": "BK-M68S-38", "name": "Mountain-200 Silver, 38", "price": 1242.8518, "quantity": 1}, {"sku": "BK-M68B-42", "name": "Mountain-200 Black, 42", "price": 1229.4589, "quantity": 2}]}
# content:  {"_id": "3618B410-02E2-4EB4-8B85-0583A82EC43D", "customerId": "35D52474-3D1A-433C-A310-10FA7DF8950B", "orderDate": "2011-12-01 00:00:00", "shipDate": "2011-12-08 00:00:00", "details": [{"sku": "BK-R50B-58", "name": "Road-650 Black, 58", "price": 419.4589, "quantity": 2}, {"sku": "BK-R68R-52", "name": "Road-450 Red, 52", "price": 874.794, "quantity": 1}, {"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 419.4589, "quantity": 2}, {"sku": "BK-R50B-52", "name": "Road-650 Black, 52", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 419.4589, "quantity": 4}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 419.4589, "quantity": 1}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 419.4589, "quantity": 1}]}
# content:  {"_id": "36AFDF73-BDFB-486D-9046-BF94D8CCB510", "customerId": "ED5B6EC1-79B6-4902-B325-F9A900854022", "orderDate": "2014-01-02 00:00:00", "shipDate": "2014-01-09 00:00:00", "details": [{"sku": "BC-R205", "name": "Road Bottle Cage", "price": 8.99, "quantity": 1}, {"sku": "WB-H098", "name": "Water Bottle - 30 oz.", "price": 4.99, "quantity": 1}]}
# content:  {"_id": "3700FA01-508F-4904-8E08-AF0C319450D0", "customerId": "E36CB859-8D01-42AE-A28F-5EBAC8C4B918", "orderDate": "2012-09-30 00:00:00", "shipDate": "2012-10-07 00:00:00", "details": [{"sku": "FR-R92B-44", "name": "HL Road Frame - Black, 44", "price": 780.8182, "quantity": 3}, {"sku": "GL-H102-L", "name": "Half-Finger Gloves, L", "price": 14.1289, "quantity": 1}, {"sku": "BK-R89R-48", "name": "Road-250 Red, 48", "price": 1466.01, "quantity": 1}, {"sku": "BK-R89B-52", "name": "Road-250 Black, 52", "price": 1308.9375, "quantity": 4}, {"sku": "BK-R89B-48", "name": "Road-250 Black, 48", "price": 1308.9375, "quantity": 1}, {"sku": "BK-R89R-52", "name": "Road-250 Red, 52", "price": 1466.01, "quantity": 3}, {"sku": "SB-M891-S", "name": "Men's Bib-Shorts, S", "price": 53.994, "quantity": 1}, {"sku": "FR-R72Y-40", "name": "ML Road Frame-W - Yellow, 40", "price": 324.4527, "quantity": 6}, {"sku": "BK-R64Y-42", "name": "Road-550-W Yellow, 42", "price": 600.2625, "quantity": 4}, {"sku": "FR-R92R-62", "name": "HL Road Frame - Red, 62", "price": 780.8182, "quantity": 1}, {"sku": "HB-R956", "name": "HL Road Handlebars", "price": 65.6018, "quantity": 2}, {"sku": "FR-R92R-44", "name": "HL Road Frame - Red, 44", "price": 780.8182, "quantity": 1}]}
# content:  {"_id": "37C7A506-823C-4A8E-A82F-10CD7E868F6F", "customerId": "9092EEDE-9BE8-4E85-B017-A243C291173E", "orderDate": "2012-07-31 00:00:00", "shipDate": "2012-08-07 00:00:00", "details": [{"sku": "FR-R92B-44", "name": "HL Road Frame - Black, 44", "price": 780.8182, "quantity": 2}, {"sku": "LJ-0192-L", "name": "Long-Sleeve Logo Jersey, L", "price": 28.8404, "quantity": 3}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 20.1865, "quantity": 3}, {"sku": "FR-R92R-44", "name": "HL Road Frame - Red, 44", "price": 780.8182, "quantity": 1}, {"sku": "CA-1098", "name": "AWC Logo Cap", "price": 5.1865, "quantity": 3}, {"sku": "BK-R50R-44", "name": "Road-650 Red, 44", "price": 469.794, "quantity": 3}, {"sku": "TG-W091-S", "name": "Women's Tights, S", "price": 44.994, "quantity": 3}, {"sku": "FW-R762", "name": "ML Road Front Wheel", "price": 149.031, "quantity": 1}, {"sku": "RW-R623", "name": "LL Road Rear Wheel", "price": 67.539, "quantity": 1}, {"sku": "FR-R38R-60", "name": "LL Road Frame - Red, 60", "price": 202.332, "quantity": 4}, {"sku": "BK-R50R-48", "name": "Road-650 Red, 48", "price": 469.794, "quantity": 3}, {"sku": "HL-U509-B", "name": "Sport-100 Helmet, Blue", "price": 20.1865, "quantity": 2}, {"sku": "SB-M891-M", "name": "Men's Bib-Shorts, M", "price": 53.994, "quantity": 4}, {"sku": "FR-R38R-44", "name": "LL Road Frame - Red, 44", "price": 202.332, "quantity": 3}, {"sku": "FR-R38B-52", "name": "LL Road Frame - Black, 52", "price": 183.9382, "quantity": 3}, {"sku": "HL-U509-R", "name": "Sport-100 Helmet, Red", "price": 20.1865, "quantity": 2}, {"sku": "TG-W091-L", "name": "Women's Tights, L", "price": 44.994, "quantity": 6}, {"sku": "FW-R820", "name": "HL Road Front Wheel", "price": 198.036, "quantity": 1}, {"sku": "BK-R50R-60", "name": "Road-650 Red, 60", "price": 469.794, "quantity": 1}, {"sku": "FR-R72Y-44", "name": "ML Road Frame-W - Yellow, 44", "price": 324.4527, "quantity": 5}, {"sku": "BK-R50R-62", "name": "Road-650 Red, 62", "price": 469.794, "quantity": 1}, {"sku": "LJ-0192-M", "name": "Long-Sleeve Logo Jersey, M", "price": 28.8404, "quantity": 3}]}
# content:  {"_id": "459CDDB0-7361-4E0C-8686-C49EE5BD3422", "customerId": "537E369C-C65B-4F23-B7C0-D07DFFFAC08B", "orderDate": "2013-12-05 00:00:00", "shipDate": "2013-12-12 00:00:00", "details": [{"sku": "TT-R982", "name": "Road Tire Tube", "price": 3.99, "quantity": 1}, {"sku": "HL-U509", "name": "Sport-100 Helmet, Black", "price": 34.99, "quantity": 1}, {"sku": "LJ-0192-X", "name": "Long-Sleeve Logo Jersey, XL", "price": 49.99, "quantity": 1}]}
# content:  {"_id": "77EA502D-A75E-4843-AC85-BF5A48764145", "customerId": "E2094914-6C88-44CC-B5F4-AA4FB78C2710", "orderDate": "2013-08-30 00:00:00", "shipDate": "2013-09-06 00:00:00", "details": [{"sku": "PK-7098", "name": "Patch Kit/8 Patches", "price": 2.29, "quantity": 1}, {"sku": "CL-9009", "name": "Bike Wash - Dissolver", "price": 7.95, "quantity": 1}, {"sku": "TT-T092", "name": "Touring Tire Tube", "price": 4.99, "quantity": 1}]}
# ---------------------------------------------------------------------------
# CursorNotFound                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Add vector field to customers documents - this will take approximately 15-20 minutes due to rate limiting
# ----> 2 add_collection_content_vector_field("sales")
#
# Cell In[19], line 29, in add_collection_content_vector_field(collection_name)
#      27 bulk_operations = []
#      28 cursor = collection.find(no_cursor_timeout=True)
# ---> 29 for doc in cursor:
#      30     # remove any previous contentVector embeddings
#      31     if "contentVector" in doc:
#      32         del doc["contentVector"]
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\cursor.py:1204, in Cursor._refresh(self)
#    1189     # Exhaust cursors don't send getMore messages.
#    1190     g = self._getmore_class(
#    1191         self.__dbname,
#    1192         self.__collname,
#    (...)
#    1202         self.__comment,
#    1203     )
# -> 1204     self.__send_message(g)
#    1206 return len(self.__data)
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\cursor.py:1060, in Cursor.__send_message(self, operation)
#    1057     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1059 try:
# -> 1060     response = client._run_operation(
#    1061         operation, self._unpack_response, address=self.__address
#    1062     )
#    1063 except OperationFailure as exc:
#    1064     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1065         # Don't send killCursors because the cursor is already closed.
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1394, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1389     operation.reset()  # Reset op in case of retry.
#    1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
# -> 1394 return self._retryable_read(
#    1395     _cmd,
#    1396     operation.read_preference,
#    1397     operation.session,
#    1398     address=address,
#    1399     retryable=isinstance(operation, message._Query),
#    1400 )
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:2445, in _ClientConnectionRetryable._read(self)
#    2443 if self._retrying and not self._retryable:
#    2444     self._check_last_error()
# -> 2445 return self._func(self._session, self._server, conn, read_pref)
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\mongo_client.py:1390, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1383 def _cmd(
#    1384     _session: Optional[ClientSession],
#    1385     server: Server,
#    1386     conn: Connection,
#    1387     read_preference: _ServerMode,
#    1388 ) -> Response:
#    1389     operation.reset()  # Reset op in case of retry.
# -> 1390     return server.run_operation(
#    1391         conn, operation, read_preference, self._event_listeners, unpack_res
#    1392     )
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\server.py:167, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res)
#     165         first = docs[0]
#     166         operation.client._process_response(first, operation.session)
# --> 167         _check_command_response(first, conn.max_wire_version)
#     168 except Exception as exc:
#     169     if publish:
#
# File c:\Users\Jaswir\Documents\Azure-OpenAI-Python-Developer-Guide\.venv\Lib\site-packages\pymongo\helpers.py:228, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     226     raise ExecutionTimeout(errmsg, code, response, max_wire_version)
#     227 elif code == 43:
# --> 228     raise CursorNotFound(errmsg, code, response, max_wire_version)
#     230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# CursorNotFound: Cursor 4317912485125541 not found, full error: {'ok': 0.0, 'errmsg': 'Cursor 4317912485125541 not found', 'code': 43, 'codeName': 'CursorNotFound'}

# %%
# Create the products vector index
db.command({
  'createIndexes': 'products',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})

# Create the customers vector index
db.command({
  'createIndexes': 'customers',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})

# Create the sales vector index
db.command({
  'createIndexes': 'sales',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 1,
#    'numIndexesAfter': 2,
#    'createdCollectionAutomatically': False,
#    'ok': 1}},
#  'ok': 1}

# %% [markdown]
# ## Use vector search in vCore-based Azure Cosmos DB for MongoDB
#
# Now that each document has its associated vector embedding and the vector indexes have been created on each collection, we can now use the vector search capabilities of vCore-based Azure Cosmos DB for MongoDB.

# %%
def vector_search(collection_name, query, num_results=3):
    """
    Perform a vector search on the specified collection by vectorizing
    the query and searching the vector index for the most similar documents.

    returns a list of the top num_results most similar documents
    """
    collection = db[collection_name]
    query_embedding = generate_embeddings(query)    
    pipeline = [
        {
            '$search': {
                "cosmosSearch": {
                    "vector": query_embedding,
                    "path": "contentVector",
                    "k": num_results
                },
                "returnStoredSource": True }},
        {'$project': { 'similarityScore': { '$meta': 'searchScore' }, 'document' : '$$ROOT' } }
    ]
    results = collection.aggregate(pipeline)
    return results

def print_product_search_result(result):
    '''
    Print the search result document in a readable format
    '''
    print(f"Similarity Score: {result['similarityScore']}")  
    print(f"Name: {result['document']['name']}")   
    print(f"Category: {result['document']['categoryName']}")
    print(f"SKU: {result['document']['categoryName']}")
    print(f"_id: {result['document']['_id']}\n")

# %%
query = "What bikes do you have?"
results = vector_search("products", query, num_results=4)
for result in results:
    print_product_search_result(result)
# Out:
# Similarity Score: 0.767089582470373
# Name: Road-750 Black, 48
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 2595584F-EA4E-4D45-948E-99A17AF8C519
#
# Similarity Score: 0.7650260697297464
# Name: Road-550-W Yellow, 40
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 3A70EDD4-6C8C-44AA-A13D-49D0F6058699
#
# Similarity Score: 0.7647035349817141
# Name: Mountain-300 Black, 48
# Category: Bikes, Mountain Bikes
# SKU: Bikes, Mountain Bikes
# _id: E8767BC9-D6BA-47FC-9842-3511468869B6
#
# Similarity Score: 0.7634958538267828
# Name: Road-550-W Yellow, 48
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 26E8185C-782A-4B48-87FA-1E715E3825FB

# %%
query = "What do you have that is yellow?"
results = vector_search("products", query, num_results=4)
for result in results:
    print_product_search_result(result)
# Out:
# Similarity Score: 0.7423481209847724
# Name: Road-550-W Yellow, 48
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 26E8185C-782A-4B48-87FA-1E715E3825FB
#
# Similarity Score: 0.7406564796362327
# Name: Road-350-W Yellow, 40
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 9E5C74FD-F685-45AE-A799-D67EFB5C28A1
#
# Similarity Score: 0.7381368591622282
# Name: Road-550-W Yellow, 40
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 3A70EDD4-6C8C-44AA-A13D-49D0F6058699
#
# Similarity Score: 0.7364529842520398
# Name: LL Touring Frame - Yellow, 62
# Category: Components, Touring Frames
# SKU: Components, Touring Frames
# _id: 91AA100C-D092-4190-92A7-7C02410F04EA

# %% [markdown]
# ## Use vector search results in a RAG pattern with Chat GPT-3.5

# %%
# A system prompt describes the responsibilities, instructions, and persona of the AI.
system_prompt = """
You are a helpful, fun and friendly sales assistant for Cosmic Works, a bicycle and bicycle accessories store. 
Your name is Cosmo.
You are designed to answer questions about the products that Cosmic Works sells.

Only answer questions related to the information provided in the list of products below that are represented
in JSON format.

If you are asked a question that is not in the list, respond with "I don't know."

List of products:
"""

# %%
def rag_with_vector_search(question: str, num_results: int = 3):
    """
    Use the RAG model to generate a prompt using vector search results based on the
    incoming question.  
    """
    # perform the vector search and build product list
    results = vector_search("products", question, num_results=num_results)
    product_list = ""
    for result in results:
        if "contentVector" in result["document"]:
            del result["document"]["contentVector"]
        product_list += json.dumps(result["document"], indent=4, default=str) + "\n\n"


    # print("product list: ", product_list)
    # generate prompt for the LLM with vector results
    formatted_prompt = system_prompt + product_list

    # prepare the LLM request
    messages = [
        {"role": "system", "content": formatted_prompt},
        {"role": "user", "content": question}
    ]

    completion = ai_client.chat.completions.create(messages=messages, model=COMPLETIONS_DEPLOYMENT_NAME)
    return completion.choices[0].message.content

# %%
print(rag_with_vector_search("What bikes do you have?", 5))
# Out:
# We have the following bikes:
# 1. Road-750 Black, 48
# 2. Road-550-W Yellow, 40
# 3. Mountain-300 Black, 48
# 4. Road-550-W Yellow, 48
# 5. Road-650 Black, 48
#
# Let me know if you need any information about any of these bikes!

# %%
print(rag_with_vector_search("What are the names and skus of yellow products?", 5))
# Out:
# The yellow products we have are:
#
# 1. Road-550-W Yellow, 48 (sku: BK-R64Y-48)
# 2. Road-550-W Yellow, 40 (sku: BK-R64Y-40)
# 3. ML Road Frame-W - Yellow, 48 (sku: FR-R72Y-48)
# 4. Road-350-W Yellow, 48 (sku: BK-R79Y-48)
# 5. Touring-3000 Yellow, 62 (sku: BK-T18Y-62)
